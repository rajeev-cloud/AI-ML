# %%
import pandas as pd
import numpy as np
import scipy as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/rajeev/PythonCode/Network_normal_backdoor/botnet.ipynb Cell 4' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/rajeev/PythonCode/Network_normal_backdoor/botnet.ipynb#ch0000003?line=0'>1</a> import pandas as pd
#       <a href='vscode-notebook-cell:/home/rajeev/PythonCode/Network_normal_backdoor/botnet.ipynb#ch0000003?line=1'>2</a> import numpy as np
#       <a href='vscode-notebook-cell:/home/rajeev/PythonCode/Network_normal_backdoor/botnet.ipynb#ch0000003?line=2'>3</a> import scipy as sns
#
# ModuleNotFoundError: No module named 'pandas'

# %%
data_csv = pd.read_csv('conn.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/rajeev/PythonCode/Network_normal_backdoor/botnet.ipynb Cell 3' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/rajeev/PythonCode/Network_normal_backdoor/botnet.ipynb#ch0000002?line=0'>1</a> data_csv = pd.read_csv('conn.csv')
#
# NameError: name 'pd' is not defined

# %%
data_csv.head()
# Out:
#    1556436597  Cdddkw1Y4af6iWhaCl  192.168.1.193  49179 192.168.1.195  5357  \
# 0  1556436597  CCyxHH24T7sLnN1fCk  192.168.1.195  57513  192.168.1.79  9197
# 1  1556436597  CiWJUk2jNItGiPncfh  192.168.1.195  57514  192.168.1.79  7678
# 2  1556436597   CC5Akyp2Mr3PPFuF2  192.168.1.195  57515  192.168.1.79  9197
# 3  1556436597  C4Tzrb2O9VTEKTBJ33  192.168.1.195  57516  192.168.1.79  7678
# 4  1556436597  CgT0Ih3pNRKONo5T27  192.168.1.195  57517  192.168.1.79  9197
#
#    tcp  http  0.002501  954  ...  SF  - -.1  0  ShADadfF  6  1206  5  2582  \
# 0  tcp  http  0.257427  169  ...  SF  -   -  0  ShADadfF  6   421  7  3770
# 1  tcp  http   0.06518  175  ...  SF  -   -  0  ShADadfF  5   387  6  1945
# 2  tcp  http  0.021509  188  ...  SF  -   -  0  ShADadfF  6   440  8  3810
# 3  tcp  http  0.025243  194  ...  SF  -   -  0  ShADadfF  5   406  6  1945
# 4  tcp  http  0.041554  132  ...  SF  -   -  0  ShADadfF  5   344  7  2062
#
#    -.2
# 0    -
# 1    -
# 2    -
# 3    -
# 4    -
#
# ...

# %%
data_csv.columns = ['time','uid', 'src_ip','src_port','dst_ip','dst_port','protocol','service', 'duration',	'src_bytes','dst_bytes','conn_state','local_orig','local_resp','missed_bytes','history','orig_pkts','src_seq','dst_seq','dst_pkts','target']

# %%
data_csv.head()
# Out:
#          time                 uid         src_ip  src_port        dst_ip  \
# 0  1556436597  CCyxHH24T7sLnN1fCk  192.168.1.195     57513  192.168.1.79
# 1  1556436597  CiWJUk2jNItGiPncfh  192.168.1.195     57514  192.168.1.79
# 2  1556436597   CC5Akyp2Mr3PPFuF2  192.168.1.195     57515  192.168.1.79
# 3  1556436597  C4Tzrb2O9VTEKTBJ33  192.168.1.195     57516  192.168.1.79
# 4  1556436597  CgT0Ih3pNRKONo5T27  192.168.1.195     57517  192.168.1.79
#
#    dst_port protocol service  duration src_bytes  ... conn_state local_orig  \
# 0      9197      tcp    http  0.257427       169  ...         SF          -
# 1      7678      tcp    http   0.06518       175  ...         SF          -
# 2      9197      tcp    http  0.021509       188  ...         SF          -
# 3      7678      tcp    http  0.025243       194  ...         SF          -
# 4      9197      tcp    http  0.041554       132  ...         SF          -
#
# ...

# %%
data_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607156 entries, 0 to 607155
# Data columns (total 21 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   time          607156 non-null  int64
#  1   uid           607156 non-null  object
#  2   src_ip        607156 non-null  object
#  3   src_port      607156 non-null  int64
#  4   dst_ip        607156 non-null  object
#  5   dst_port      607156 non-null  int64
#  6   protocol      607156 non-null  object
#  7   service       607156 non-null  object
#  8   duration      607156 non-null  object
#  9   src_bytes     607156 non-null  object
#  10  dst_bytes     607156 non-null  object
#  11  conn_state    607156 non-null  object
#  12  local_orig    607156 non-null  object
#  13  local_resp    607156 non-null  object
#  14  missed_bytes  607156 non-null  int64
#  15  history       607156 non-null  object
#  16  orig_pkts     607156 non-null  int64
# ...

# %%
data_csv.head(10)
# Out:
#          time                 uid         src_ip  src_port        dst_ip  \
# 0  1556436597  CCyxHH24T7sLnN1fCk  192.168.1.195     57513  192.168.1.79
# 1  1556436597  CiWJUk2jNItGiPncfh  192.168.1.195     57514  192.168.1.79
# 2  1556436597   CC5Akyp2Mr3PPFuF2  192.168.1.195     57515  192.168.1.79
# 3  1556436597  C4Tzrb2O9VTEKTBJ33  192.168.1.195     57516  192.168.1.79
# 4  1556436597  CgT0Ih3pNRKONo5T27  192.168.1.195     57517  192.168.1.79
# 5  1556436597  Ch2MuF4ZmlrCKkAmY9  192.168.1.195     57518  192.168.1.79
# 6  1556436597  CvNXg93VApcwZNWJHg  192.168.1.195     57519  192.168.1.79
# 7  1556436597  CLje0H2bEiXvbalXth  192.168.1.195     57520  192.168.1.79
# 8  1556436597  CS8pPt4s9X7Q366hBh  192.168.1.195     57521  192.168.1.79
# 9  1556436597  CsCcYD1hqFZayw1bMk  192.168.1.195     57523  192.168.1.79
#
#    dst_port protocol service  duration src_bytes  ... conn_state local_orig  \
# 0      9197      tcp    http  0.257427       169  ...         SF          -
# ...

# %%
data_csv.tail(10)
# Out:
#               time                 uid         src_ip  src_port  \
# 607146  1556531133  CcmrUu4zW5LJLPN7ph  192.168.1.193     51732
# 607147  1556531096  C8PIZW2PXOP5xmiyyk  192.168.1.195     49948
# 607148  1556531101  Cn30Ll4loH40BdQC4e    192.168.1.1     53973
# 607149  1556515016  CIIKDS1bhFA7fL75v1  192.168.1.195     61574
# 607150  1556531099  Cac2aw2wgC6kDGdUp2    192.168.1.1     65040
# 607151  1556531099  CEIBzz42U6AEReLdVh    192.168.1.1     51587
# 607152  1556531106  CuEuzX3Z9di2jkKjF4   192.168.1.79     33989
# 607153  1556531127  C8YiwL27KQ006yLSX5    192.168.1.1       138
# 607154  1556531106  CNCJ4B43H8MOfljXAg   192.168.1.79     43382
# 607155  1556531096  CmR6IF3Ee5Rk5Nadsh    192.168.1.1     56504
#
#                  dst_ip  dst_port protocol service     duration src_bytes  \
# 607146     192.168.1.33      8080      tcp       -     0.000425         0
# 607147  239.255.255.250      1900      udp       -     3.264848      2468
# ...

# %%
pd.crosstab(data_csv.conn_state,data_csv.protocol)
# Out:
# protocol    icmp     tcp    udp
# conn_state
# OTH          994   34449      0
# REJ            0  507846      0
# RSTO           0     113      0
# RSTOS0         0     259      0
# RSTR           0     286      0
# RSTRH          0     926      0
# S0             0    2298  25877
# S1             0      26      0
# S3             0       1      0
# SF             0   16588  12857
# SH             0    3241      0
# SHR            0      81   1314

# %%
data_csv.shape
# Out:
# (607156, 21)

# %%
set(data_csv.conn_state)
# Out:
# {'OTH',
#  'REJ',
#  'RSTO',
#  'RSTOS0',
#  'RSTR',
#  'RSTRH',
#  'S0',
#  'S1',
#  'S3',
#  'SF',
#  'SH',
#  'SHR'}

# %%
data_csv.conn_state.value_counts()/data_csv.shape[0]
# Out:
# REJ       0.836434
# OTH       0.058375
# SF        0.048497
# S0        0.046405
# SH        0.005338
# SHR       0.002298
# RSTRH     0.001525
# RSTR      0.000471
# RSTOS0    0.000427
# RSTO      0.000186
# S1        0.000043
# S3        0.000002
# Name: conn_state, dtype: float64

# %%
set(data_csv.service)
# Out:
# {'-', 'dce_rpc', 'dhcp', 'dns', 'gssapi', 'http', 'smb', 'smb,gssapi', 'ssl'}

# %%
data_csv.service.value_counts()
# Out:
# -             569725
# dns            21269
# http           15369
# ssl              490
# smb              108
# gssapi           100
# dce_rpc           76
# smb,gssapi        18
# dhcp               1
# Name: service, dtype: int64

# %%
#del data_csv['uid']
#del data_csv['protocol']
#del data_csv['service']

# %%
data_csv.describe()
# Out:
#                time       src_port       dst_port   missed_bytes  \
# count  6.071560e+05  607156.000000  607156.000000  607156.000000
# mean   1.556484e+09   53827.420749    7255.169164       6.975726
# std    2.987207e+04   11580.625169   11465.122541    1093.502371
# min    1.556434e+09       3.000000       0.000000       0.000000
# 25%    1.556457e+09   50991.000000      80.000000       0.000000
# 50%    1.556488e+09   55676.000000    8080.000000       0.000000
# 75%    1.556510e+09   60494.000000    8080.000000       0.000000
# max    1.556531e+09   65535.000000   65519.000000  458618.000000
#
#            orig_pkts       src_seq        dst_seq      dst_pkts
# count  607156.000000  6.071560e+05  607156.000000  6.071560e+05
# mean        1.593447  1.761990e+02       1.652579  5.889863e+02
# std       136.598309  1.660673e+04     236.273853  1.530879e+05
# min         0.000000  0.000000e+00       0.000000  0.000000e+00
# ...

# %%
data_csv.shape
# Out:
# (607156, 21)

# %%
service_dummy = pd.get_dummies(data_csv.conn_state,prefix='service')
protcol_dummy = pd.get_dummies(data_csv.dst_port,prefix='protocol')

# %%
full_data = pd.concat([data_csv,service_dummy,protcol_dummy],axis=1)

# %%
list(full_data.columns)
# Out:
# ['time',
#  'uid',
#  'src_ip',
#  'src_port',
#  'dst_ip',
#  'dst_port',
#  'protocol',
#  'service',
#  'duration',
#  'src_bytes',
#  'dst_bytes',
#  'conn_state',
#  'local_orig',
#  'local_resp',
#  'missed_bytes',
#  'history',
#  'orig_pkts',
#  'src_seq',
#  'dst_seq',
#  'dst_pkts',
#  'target',
#  'service_OTH',
#  'service_REJ',
#  'service_RSTO',
#  'service_RSTOS0',
#  'service_RSTR',
#  'service_RSTRH',
#  'service_S0',
#  'service_S1',
#  'service_S3',
#  'service_SF',
#  'service_SH',
#  'service_SHR',
#  'protocol_0',
#  'protocol_3',
#  'protocol_7',
#  'protocol_14',
#  'protocol_43',
#  'protocol_53',
#  'protocol_67',
#  'protocol_80',
#  'protocol_123',
#  'protocol_133',
#  'protocol_134',
#  'protocol_135',
#  'protocol_136',
#  'protocol_137',
#  'protocol_138',
#  'protocol_443',
#  'protocol_445',
#  'protocol_547',
#  'protocol_1124',
#  'protocol_1880',
#  'protocol_1900',
#  'protocol_2869',
#  'protocol_3289',
#  'protocol_3702',
#  'protocol_4444',
# ...

# %%
full_data.shape
# Out:
# (607156, 2621)

# %%
y = full_data.pop('conn_state')

# %%
x = full_data

# %%
y
# Out:
# 0         SF
# 1         SF
# 2         SF
# 3         SF
# 4         SF
#           ..
# 607151    S0
# 607152    S0
# 607153    S0
# 607154    S0
# 607155    S0
# Name: conn_state, Length: 607156, dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain, ytest = train_test_split(x,y,test_size=0.30,random_state=707)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/rajeev/PythonCode/Network_normal_backdoor/botnet.ipynb Cell 2' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/home/rajeev/PythonCode/Network_normal_backdoor/botnet.ipynb#ch0000001?line=0'>1</a> xtrain,xtest,ytrain, ytest = train_test_split(x,y,test_size=0.30,random_state=707)
#
# NameError: name 'train_test_split' is not defined
